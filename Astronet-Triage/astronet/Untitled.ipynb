# %%
import matplotlib.pyplot as plt
import numpy as np
import os.path
import tensorflow as tf

# %%
TFRECORD_DIR1 = r"D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\tfrecords"
TFRECORD_DIR2 = r"D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\data\inputrecords2"
TFRECORD_DIR3 = r"D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\data\inputrecords"
TFRECORD_DIR4 = r"D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\data\inputrecordsinverted"
TFRECORD_DIRX = r"D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\data\inputrecords1206"
TFRECORD_DIRY = r"D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\data\s001"

# %%
TFRECORD_DIRZ = r"D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\data\s002_new"

# %%
# Helper function to find the tf.Example corresponding to a particular TCE.
def find_tce(tic_id, filenames):
  for filename in filenames:
    for record in tf.python_io.tf_record_iterator(filename):
      ex = tf.train.Example.FromString(record)
      if ex.features.feature["tic_id"].int64_list.value[0] == tic_id:
        print("Found {} in file {}".format(tic_id, filename))
        return ex
        raise ValueError("{} not found in files: {}".format(tic_id, filenames))

# %%
TIC_ID = 149248969

# %%
TIC_ID=269830039

# %%
# Find sample TCE
filenames1 = tf.gfile.Glob(os.path.join(TFRECORD_DIR1, "*"))
assert filenames1, "No files found in {}".format(TFRECORD_DIR1)
ex1 = find_tce(TIC_ID, filenames1)
print(ex1)
# Out:
# Found 149248969 in file D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\tfrecords\train-00003-of-00008
# features {
#   feature {
#     key: "Disposition"
#     value {
#       bytes_list {
#         value: "EB"
#       }
#     }
#   }
#   feature {
#     key: "Duration"
#     value {
#       float_list {
#         value: 0.09533250331878662
#       }
#     }
#   }
#   feature {
#     key: "Epoc"
#     value {
#       float_list {
#         value: 1325.7564697265625
#       }
#     }
#   }
#   feature {
#     key: "Period"
#     value {
#       float_list {
#         value: 0.2518160045146942
#       }
#     }
#   }
#   feature {
#     key: "SN"
#     value {
#       float_list {
#         value: 71.40013122558594
#       }
#     }
#   }
#   feature {
#     key: "Sectors"
#     value {
#       int64_list {
#         value: 4
#       }
#     }
#   }
#   feature {
#     key: "Transit_Depth"
#     value {
#       float_list {
#         value: 1280.0
#       }
#     }
#   }
# ...

# %%
# Find sample TCE
filenamesX = tf.gfile.Glob(os.path.join(TFRECORD_DIRX, "*"))
assert filenamesX, "No files found in {}".format(TFRECORD_DIRX)
exX = find_tce(TIC_ID, filenamesX)
print(exX)
# Out:
# WARNING:tensorflow:From C:\Users\ENDOTA~1\AppData\Local\Temp/ipykernel_18392/3624770865.py:2: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# WARNING:tensorflow:From C:\Users\ENDOTA~1\AppData\Local\Temp/ipykernel_18392/1536330924.py:4: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# Found 149248969 in file D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\data\inputrecords1206\train-00003-of-00008
# features {
#   feature {
#     key: "Disposition"
#     value {
#       bytes_list {
#         value: "EB"
#       }
#     }
#   }
#   feature {
#     key: "Duration"
#     value {
#       float_list {
#         value: 0.09533250331878662
#       }
#     }
#   }
#   feature {
#     key: "Epoc"
#     value {
#       float_list {
#         value: 1325.7564697265625
#       }
#     }
#   }
# ...

# %%
# Find sample TCE
filenamesY = tf.gfile.Glob(os.path.join(TFRECORD_DIRY, "*"))
assert filenamesY, "No files found in {}".format(TFRECORD_DIRY)
exY = find_tce(TIC_ID, filenamesY)
print(exY)
# Out:
# Found 269830039 in file D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\data\s001\test-00006-of-00008
# features {
#   feature {
#     key: "Dec"
#     value {
#       int64_list {
#         value: 0
#       }
#     }
#   }
#   feature {
#     key: "Disposition"
#     value {
#       bytes_list {
#         value: "J"
#       }
#     }
#   }
#   feature {
#     key: "Duration"
#     value {
#       float_list {
#         value: 0.1046316996216774
#       }
#     }
#   }
#   feature {
#     key: "Epoc"
#     value {
#       float_list {
#         value: 5.007603168487549
#       }
#     }
#   }
#   feature {
#     key: "Period"
#     value {
#       float_list {
#         value: 8.928571701049805
#       }
#     }
#   }
#   feature {
#     key: "Qingress"
#     value {
#       int64_list {
#         value: 0
#       }
#     }
#   }
#   feature {
#     key: "RA"
#     value {
#       int64_list {
#         value: 0
#       }
#     }
#   }
#   feature {
#     key: "SN"
# ...

# %%
# Find sample TCE
filenamesZ = tf.gfile.Glob(os.path.join(TFRECORD_DIRZ, "*"))
assert filenamesZ, "No files found in {}".format(TFRECORD_DIRZ)
exZ = find_tce(TIC_ID, filenamesZ)
print(exZ)
# Out:
# Found 66436964 in file D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\data\s002_new\train-00001-of-00008
# features {
#   feature {
#     key: "Dec"
#     value {
#       int64_list {
#         value: 0
#       }
#     }
#   }
#   feature {
#     key: "Disposition"
#     value {
#       bytes_list {
#         value: "J"
#       }
#     }
#   }
#   feature {
#     key: "Duration"
#     value {
#       float_list {
#         value: 0.1034402847290039
#       }
#     }
#   }
#   feature {
#     key: "Epoc"
#     value {
#       float_list {
#         value: -0.8448395729064941
#       }
#     }
#   }
#   feature {
#     key: "Period"
#     value {
#       float_list {
#         value: 8.826904296875
#       }
#     }
#   }
#   feature {
#     key: "Qingress"
#     value {
#       int64_list {
#         value: 0
#       }
#     }
#   }
#   feature {
#     key: "RA"
#     value {
#       int64_list {
#         value: 0
#       }
#     }
#   }
#   feature {
#     key: "SN"
# ...

# %%
# Find sample TCE
filenames2 = tf.gfile.Glob(os.path.join(TFRECORD_DIR2, "*"))
assert filenames2, "No files found in {}".format(TFRECORD_DIR2)
ex2 = find_tce(TIC_ID, filenames2)
print(ex2)
# Out:
# Found 149248969 in file D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\data\inputrecords2\train-00003-of-00008
# features {
#   feature {
#     key: "Disposition"
#     value {
#       bytes_list {
#         value: "EB"
#       }
#     }
#   }
#   feature {
#     key: "Duration"
#     value {
#       float_list {
#         value: 0.09533250331878662
#       }
#     }
#   }
#   feature {
#     key: "Epoc"
#     value {
#       float_list {
#         value: 1325.7564697265625
#       }
#     }
#   }
#   feature {
#     key: "Period"
#     value {
#       float_list {
#         value: 0.2518160045146942
#       }
#     }
#   }
#   feature {
#     key: "SN"
#     value {
#       float_list {
#         value: 71.40013122558594
#       }
#     }
#   }
#   feature {
#     key: "Sectors"
#     value {
#       int64_list {
#         value: 4
#       }
#     }
#   }
#   feature {
#     key: "Transit_Depth"
#     value {
#       float_list {
#         value: 1280.0
#       }
#     }
# ...

# %%
# Find sample TCE
filenames3 = tf.gfile.Glob(os.path.join(TFRECORD_DIR3, "*"))
assert filenames3, "No files found in {}".format(TFRECORD_DIR3)
ex3 = find_tce(TIC_ID, filenames3)
print(ex3)
# Out:
# Found 149248969 in file D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\data\inputrecords\train-00003-of-00008
# features {
#   feature {
#     key: "Disposition"
#     value {
#       bytes_list {
#         value: "EB"
#       }
#     }
#   }
#   feature {
#     key: "Duration"
#     value {
#       float_list {
#         value: 0.09533250331878662
#       }
#     }
#   }
#   feature {
#     key: "Epoc"
#     value {
#       float_list {
#         value: 1325.7564697265625
#       }
#     }
#   }
#   feature {
#     key: "Period"
#     value {
#       float_list {
#         value: 0.2518160045146942
#       }
#     }
#   }
#   feature {
#     key: "SN"
#     value {
#       float_list {
#         value: 71.40013122558594
#       }
#     }
#   }
#   feature {
#     key: "Sectors"
#     value {
#       int64_list {
#         value: 4
#       }
#     }
#   }
#   feature {
#     key: "Transit_Depth"
#     value {
#       float_list {
#         value: 1280.0
#       }
#     }
# ...

# %%
# Find sample TCE
filenames4 = tf.gfile.Glob(os.path.join(TFRECORD_DIR4, "*"))
assert filenames4, "No files found in {}".format(TFRECORD_DIR4)
ex4 = find_tce(TIC_ID, filenames4)
print(ex4)
# Out:
# WARNING:tensorflow:From C:\Users\ENDOTA~1\AppData\Local\Temp/ipykernel_14320/2259767894.py:2: The name tf.gfile.Glob is deprecated. Please use tf.io.gfile.glob instead.
#
# WARNING:tensorflow:From C:\Users\ENDOTA~1\AppData\Local\Temp/ipykernel_14320/1536330924.py:4: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# Found 149248969 in file D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\astronet\data\inputrecordsinverted\train-00003-of-00008
# features {
#   feature {
#     key: "Disposition"
#     value {
#       bytes_list {
#         value: "EB"
#       }
#     }
#   }
#   feature {
#     key: "Duration"
#     value {
#       float_list {
#         value: 0.09533250331878662
#       }
#     }
#   }
#   feature {
#     key: "Epoc"
#     value {
#       float_list {
#         value: 1325.7564697265625
#       }
#     }
#   }
# ...

# %%
# Plot the global and local views.
global_view1 = np.array(ex1.features.feature["global_view"].float_list.value)
local_view1 = np.array(ex1.features.feature["local_view"].float_list.value)
print(np.mean(global_view1))
print(np.min(global_view1))
print(np.mean(local_view1))
print(np.min(local_view1))
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(global_view1, ".")
axes[1].plot(local_view1, ".")
plt.show()
# Out:
# -0.11214553243457455
# -1.0
# -0.18311430476453217
# -1.0

# %%
# Plot the global and local views.
global_viewX = np.array(exX.features.feature["global_view"].float_list.value)
local_viewX = np.array(exX.features.feature["local_view"].float_list.value)
print(np.mean(global_viewX))
print(np.min(global_viewX))
print(np.mean(local_viewX))
print(np.min(local_viewX))
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(global_viewX, ".")
axes[1].plot(local_viewX, ".")
plt.show()
# Out:
# -0.03592086670716381
# -1.0
# -0.1399783713391936
# -1.0

# %%
# Plot the global and local views.
global_viewY= np.array(exY.features.feature["global_view"].float_list.value)
local_viewY = np.array(exY.features.feature["local_view"].float_list.value)
print(np.mean(global_viewY))
print(np.min(global_viewY))
print(np.mean(local_viewY))
print(np.min(local_viewY))
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(global_viewY, ".")
axes[1].plot(local_viewY, ".")
plt.show()
# Out:
# -0.007011725851401622
# -1.0
# -0.16796579839447973
# -1.0

# %%
# Plot the global and local views.
global_viewZ= np.array(exZ.features.feature["global_view"].float_list.value)
local_viewZ = np.array(exZ.features.feature["local_view"].float_list.value)
print(np.mean(global_viewZ))
print(np.min(global_viewZ))
print(np.mean(local_viewZ))
print(np.min(local_viewZ))
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(global_viewZ, ".")
axes[1].plot(local_viewZ, ".")
plt.show()
# Out:
# -0.010958071546848436
# -1.0
# -0.1995787537450612
# -1.0

# %%
# Plot the global and local views.
global_view2 = np.array(ex2.features.feature["global_view"].float_list.value)
local_view2 = np.array(ex2.features.feature["local_view"].float_list.value)
print(np.mean(global_view2))
print(np.min(global_view2))
print(np.mean(local_view2))
print(np.min(local_view2))
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(-global_view2, ".")
axes[1].plot(local_view2, ".")
plt.show()
# Out:
# 0.07931797518696061
# -1.0
# 0.8994817180620109
# -1.0

# %%
# Plot the global and local views.
global_view3 = np.array(ex3.features.feature["global_view"].float_list.value)
local_view3 = np.array(ex3.features.feature["local_view"].float_list.value)
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(global_view3, ".")
axes[1].plot(local_view3, ".")
plt.show()

# %%
# Plot the global and local views.
global_view4 = np.array(ex4.features.feature["global_view"].float_list.value)
local_view4 = np.array(ex4.features.feature["local_view"].float_list.value)
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(global_view4, ".")
axes[1].plot(local_view4, ".")
plt.show()

# %%
# !echo %PYTHONPATH%
# Out:
# D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage

# %%
from light_curve_util import tess_io

# %%
time,flux=tess_io.read_tess_light_curve(tess_io.tess_filenames(TIC_ID))
plt.plot(time,flux, ".")
# Out:
# WARNING:tensorflow:From D:\SynologyDrive\Univ\kenkyuu\Astronet-Triage\light_curve_util\tess_io.py:72: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.

# %%
from astronet.data import preprocess

# %%
time,flux=preprocess.read_and_process_light_curve(TIC_ID)
time2,flux2=tess_io.read_tess_light_curve(tess_io.tess_filenames(TIC_ID))
ftime,fflux=preprocess.phase_fold_and_sort_light_curve(time,flux,0.251816,1325.756517)
ftime2,fflux2=preprocess.phase_fold_and_sort_light_curve(time2,flux2,0.251816,1325.756517)
fflux3=fflux+fflux2
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(ftime,fflux3, ".")
axes[1].plot(ftime,fflux, ".")

# %%
from light_curve_util import tess_io_old
timeo,fluxo=tess_io_old.read_tess_light_curve(tess_io_old.tess_filenames(TIC_ID))
fig,axes=plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(time,flux, ".")
axes[1].plot(timeo,fluxo, ".")
# Out:
# [1325.65696933 1325.67780278 1325.71946966 1325.76113655 1325.78197
#  1325.86530378 1325.88613723 1326.01113794 1326.0736383  1326.09447175
#  1326.1153052  1326.15697211 1326.17780557 1326.19863902 1326.21947248
#  1326.24030593 1326.26113939 1326.28197285 1326.3028063  1326.32363976
#  1326.36530668 1326.38614014 1326.40697359 1326.42780705 1326.44864051
#  1326.49030743 1326.51114089 1326.53197435 1326.55280781 1326.57364127
#  1326.59447473 1326.61530819 1326.65697511 1326.69864203 1326.71947549
#  1326.74030895 1326.76114241 1326.78197587 1326.80280933 1326.88614318
#  1326.9278101  1326.94864356 1327.01114395 1327.03197741 1327.05281087
#  1327.07364433 1327.09447779 1327.11531126 1327.21947857 1327.24031203
#  1327.26114549 1327.28197895 1327.30281241 1327.32364588 1327.34447934
#  1327.3653128  1327.38614626 1327.40697972 1327.42781319 1327.44864665
#  1327.49031357 1327.51114703 1327.5319805  1327.55281396 1327.57364742
# ...

# %%
ftimeo,ffluxo=preprocess.phase_fold_and_sort_light_curve(timeo,fluxo,0.251816,1325.756517)
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(ftime,fflux, ".")
axes[1].plot(ftimeo,ffluxo, ".")

# %%
print(ftimeo)
viewg=preprocess.global_view(ftimeo,ffluxo,0.251816)
viewl=preprocess.local_view(ftimeo,ffluxo,0.251816,2.287980031/24)
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(viewg, ".")
axes[1].plot(viewl, ".")
# Out:
# [-1.25892635e-01 -1.25824865e-01 -1.25264836e-01 -1.25180039e-01
#  -1.25108563e-01 -1.25022777e-01 -1.24950641e-01 -1.24157411e-01
#  -1.24077911e-01 -1.23448979e-01 -1.23365144e-01 -1.23207766e-01
#  -1.23136127e-01 -1.22421403e-01 -1.22263208e-01 -1.22195767e-01
#  -1.21633203e-01 -1.21550272e-01 -1.21392786e-01 -1.21321627e-01
#  -1.20606748e-01 -1.20526349e-01 -1.20448524e-01 -1.19817503e-01
#  -1.19735421e-01 -1.19577837e-01 -1.19507139e-01 -1.18792106e-01
#  -1.18710922e-01 -1.18633861e-01 -1.18001874e-01 -1.17920591e-01
#  -1.17762917e-01 -1.17692662e-01 -1.16977475e-01 -1.16819216e-01
#  -1.16186308e-01 -1.16105781e-01 -1.15948025e-01 -1.15878193e-01
#  -1.15080249e-01 -1.15004589e-01 -1.14370802e-01 -1.14290991e-01
#  -1.14133160e-01 -1.14063732e-01 -1.13348239e-01 -1.13264992e-01
#  -1.13189980e-01 -1.12555349e-01 -1.12476219e-01 -1.12318320e-01
#  -1.12249276e-01 -1.11533629e-01 -1.11449783e-01 -1.11375389e-01
# ...

# %%
viewg2=preprocess.global_view(ftime2,fflux2,0.251816)
viewl2=preprocess.local_view(ftime2,fflux2,0.251816,2.287980031/24)
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(viewg2, ".")
axes[1].plot(viewl2, ".")

# %%
viewgf=preprocess.global_view(ftime,fflux,0.251816)
viewlf=preprocess.local_view(ftime,fflux,0.251816,2.287980031/24)
fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(viewgf, ".")
axes[1].plot(viewlf, ".")

# %%
time, flux = preprocess.read_and_process_light_curve(TIC_ID, sector=1, is_multi=False)
time, flux = preprocess.phase_fold_and_sort_light_curve(time, flux, 0.251816, 1325.756517)
# Generate the local and global views.
global_view = preprocess.global_view(time, flux, 0.251816)
local_view = preprocess.local_view(time, flux, 0.251816, 2.287980031/24)

fig, axes = plt.subplots(1, 2, figsize=(20, 6))
axes[0].plot(global_view, ".")
axes[1].plot(local_view, ".")
