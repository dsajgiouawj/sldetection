# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import time
import matplotlib.pyplot as plt
import math
import numpy as np

# %%
d1=np.loadtxt("/home/kawahara/gbls/SDE_P1.txt",delimiter=",")
d2=np.loadtxt("/home/kawahara/gbls/SDE_P2.txt",delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-8c3c0a0269a7> in <module>()
# ----> 1 d1=np.loadtxt("/home/kawahara/gbls/SDE_P.txt",delimiter=",")
#       2 d2=np.loadtxt("/home/kawahara/gbls/SDE_P.txt",delimiter=",")
#
# /home/kawahara/anaconda3/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     803                 fh = iter(open(fname, 'U'))
#     804             else:
# --> 805                 fh = iter(open(fname))
#     806         else:
#     807             fh = iter(fname)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/kawahara/gbls/SDE_P.txt'

# %%
d1.shape,d2.shape
# Out:
# ((399, 2), (390, 2))

# %%
fig=plt.figure(figsize=(5,5))
ax=fig.add_subplot(211)
ax.plot(d1[:,0],d1[:,1],".")
ax.plot(d2[:,0],d2[:,1],".")
#plt.xlabel("SDE")
plt.ylabel("P")
ax=fig.add_subplot(212)
ax.hist(np.concatenate([d1[:,0],d2[:,0]]),bins=50)
plt.xlabel("SDE")
plt.ylabel("#")
plt.savefig("sdedist.png")
plt.show()
